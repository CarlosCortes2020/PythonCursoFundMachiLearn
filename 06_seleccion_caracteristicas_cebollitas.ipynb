# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_partidos = pd.read_csv('partidos_cebollitas.csv')
df_partidos['diferencia_goles'] = df_partidos['goles_local'] - df_partidos['goles_visitante']
df_partidos['ratio_tiros_posesion_local'] = df_partidos['tiros_arco_local'] / df_partidos['posesion_local (%)']
df_partidos['ratio_tiros_posesion_visitante'] = df_partidos['tiros_arco_visitante'] / df_partidos['posesion_visitante (%)']


df_partidos.head()
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python    Cebollitas FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15    Cebollitas FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United    Cebollitas FC            5
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
#
#    tiros_arco_local  tiros_arco_visitante       estadio  diferencia_goles  \
# 0                12                     6  Python Arena                 2
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_regression

#Variables predictoras y objetivo
X = df_partidos[['posesion_local (%)','tiros_arco_local', 'ratio_tiros_posesion_local']]
y = df_partidos['goles_local']

#Seleccionar las mejores caracteristicas
selector = SelectKBest(score_func=f_regression, k=2)
X_new = selector.fit(X, y)

#Resultados ordenados por relevancia
scores = selector.scores_
variables = X.columns

resultados = pd.DataFrame({'Variable': variables, 'Score': scores}).sort_values(by='Score', ascending=False)
print(resultados)
# Out:
#                      Variable     Score
# 0          posesion_local (%)  2.844159
# 2  ratio_tiros_posesion_local  2.323320
# 1            tiros_arco_local  1.372691

# %%
#Entrenar arbol de decision para medir importancia
from sklearn.tree import DecisionTreeRegressor
modelo_arbol = DecisionTreeRegressor(random_state=42)
modelo_arbol.fit(X, y)

importancia = modelo_arbol.feature_importances_
resultado_importancia = pd.DataFrame({'Variable': variables, 'Importancia': importancia}).sort_values(by='Importancia', ascending=False)
print(resultado_importancia)
# Out:
#                      Variable  Importancia
# 0          posesion_local (%)     0.491563
# 2  ratio_tiros_posesion_local     0.305755
# 1            tiros_arco_local     0.202683

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

#Grafica SelectKbest (analisis univariado)
sns.barplot(x='Score', y='Variable', data=resultados, ax=ax[0], palette='Blues_r')
ax[0].set_title('Importancia de Caracteristicas (SelectKBest)')
ax[0].set_xlabel('Score')
ax[0].set_ylabel('Variable')

#Grafica Decision Tree (analisis multivariado)
sns.barplot(x='Importancia', y='Variable', data=resultado_importancia, ax=ax[1], palette='Greens_r')
ax[1].set_title('Importancia de Caracteristicas (Decision Tree)')
ax[1].set_xlabel('Importancia')
ax[1].set_ylabel('Variable')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_52765/787151002.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score', y='Variable', data=resultados, ax=ax[0], palette='Blues_r')
# /tmp/ipykernel_52765/787151002.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importancia', y='Variable', data=resultado_importancia, ax=ax[1], palette='Greens_r')
